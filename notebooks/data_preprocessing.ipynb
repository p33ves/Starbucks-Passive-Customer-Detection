# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Importing required libraries and reading the input json files:

# %%
import os, datetime, json
import pandas as pd
import numpy as np

# %%
transcript = pd.read_json('../data/transcript.json', orient='records', lines=True)
portfolio = pd.read_json('../data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('../data/profile.json', orient='records', lines=True)

# %% [markdown]
# ## Data cleansing operations

# %% [markdown]
# ### Cleaning profile.json

# %%
profile.shape
# Out:
# (17000, 5)

# %%
profile.dropna(axis=0,inplace=True)
profile.rename(columns={'id': 'cust_id'}, inplace=True)
profile['became_member_on'] = pd.to_datetime(profile['became_member_on'].astype(str), format='%Y%m%d')
profile['days_as_member'] = (datetime.datetime.today() - profile['became_member_on']).dt.days
profile.sample(10)
# Out:
#       gender  age                           cust_id became_member_on  \
# 13335      M   42  6a048964e72d420eb28dcacabdfe4526       2018-05-26
# 4468       M   43  a4ecd1ebb16a4800bdbf57aaf0144078       2018-07-11
# 12002      M   68  0a34323c7f254960979fb7c6cafa6b3c       2015-02-10
# 425        M   51  227f2d69e46a4899b70d48182822cff6       2018-05-12
# 7564       M   66  db06532760134014aa9445c7560554af       2017-06-06
# 9954       M   48  be36abf9679d4981963d4af7d14eeafe       2017-12-03
# 11349      F   55  d5ea4111ae9c4ccb998c0019c91c9329       2017-09-07
# 12964      M   53  6c3846ea64974f65bfa6611706e769a5       2017-10-08
# 6939       M   67  a1cf198e6f334dcb9a4a4f6d8f6d4b84       2013-08-28
# 13         F   61  aa4862eba776480b8bb9c68455b8c2e1       2017-09-11
#
#          income  days_as_member
# 13335   64000.0             913
# 4468    93000.0             867
# 12002   70000.0            2114
# 425    100000.0             927
# 7564    92000.0            1267
# 9954    45000.0            1087
# 11349   54000.0            1174
# 12964   46000.0            1143
# 6939    63000.0            2645
# 13      57000.0            1170

# %%
profile.to_csv('../data/cln_profile.csv')

# %% [markdown]
# ### Cleaning portfolio.json

# %%
portfolio.rename(columns={'id': 'offer_id'}, inplace=True)
portfolio.set_index('offer_id', inplace=True)
portfolio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, ae264e3637204a6fb9bb56bc8210ddfd to 2906b810c7d4411798c6938adc9daaa5
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reward      10 non-null     int64
#  1   channels    10 non-null     object
#  2   difficulty  10 non-null     int64
#  3   duration    10 non-null     int64
#  4   offer_type  10 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 480.0+ bytes

# %% [markdown]
# #### Unpacking channels

# %%
medium = portfolio['channels'].str.join(',').str.get_dummies(',')
portfolio = pd.concat([portfolio, medium], axis=1) # concat medium columns
portfolio = portfolio.drop(['channels'], axis=1)
portfolio['duration_in_hours'] = portfolio['duration']*24
portfolio
# Out:
#                                   reward  difficulty  duration     offer_type  \
# offer_id
# ae264e3637204a6fb9bb56bc8210ddfd      10          10         7           bogo
# 4d5c57ea9a6940dd891ad53e9dbe8da0      10          10         5           bogo
# 3f207df678b143eea3cee63160fa8bed       0           0         4  informational
# 9b98b8c7a33c4b65b9aebfe6a799e6d9       5           5         7           bogo
# 0b1e1539f2cc45b7b9fa7c272da2e1d7       5          20        10       discount
# 2298d6c36e964ae4a3e7e9706d1fb8c2       3           7         7       discount
# fafdcd668e3743c1bb461111dcafc2a4       2          10        10       discount
# 5a8bc65990b245e5a138643cd4eb9837       0           0         3  informational
# f19421c1d4aa40978ebb69ca19b0e20d       5           5         5           bogo
# 2906b810c7d4411798c6938adc9daaa5       2          10         7       discount
#
#                                   email  mobile  social  web  \
# offer_id
# ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 3f207df678b143eea3cee63160fa8bed      1       1       0    1
# 9b98b8c7a33c4b65b9aebfe6a799e6d9      1       1       0    1
# 0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1
# 2298d6c36e964ae4a3e7e9706d1fb8c2      1       1       1    1
# fafdcd668e3743c1bb461111dcafc2a4      1       1       1    1
# 5a8bc65990b245e5a138643cd4eb9837      1       1       1    0
# f19421c1d4aa40978ebb69ca19b0e20d      1       1       1    1
# 2906b810c7d4411798c6938adc9daaa5      1       1       0    1
#
#                                   duration_in_hours
# offer_id
# ae264e3637204a6fb9bb56bc8210ddfd                168
# 4d5c57ea9a6940dd891ad53e9dbe8da0                120
# 3f207df678b143eea3cee63160fa8bed                 96
# 9b98b8c7a33c4b65b9aebfe6a799e6d9                168
# 0b1e1539f2cc45b7b9fa7c272da2e1d7                240
# 2298d6c36e964ae4a3e7e9706d1fb8c2                168
# fafdcd668e3743c1bb461111dcafc2a4                240
# 5a8bc65990b245e5a138643cd4eb9837                 72
# f19421c1d4aa40978ebb69ca19b0e20d                120
# 2906b810c7d4411798c6938adc9daaa5                168

# %%
portfolio.drop(['duration'], axis=1, inplace=True)
portfolio.rename(columns={'duration_in_hours':'duration'},inplace=True)
portfolio
# Out:
#                                   reward  difficulty     offer_type  email  \
# offer_id
# ae264e3637204a6fb9bb56bc8210ddfd      10          10           bogo      1
# 4d5c57ea9a6940dd891ad53e9dbe8da0      10          10           bogo      1
# 3f207df678b143eea3cee63160fa8bed       0           0  informational      1
# 9b98b8c7a33c4b65b9aebfe6a799e6d9       5           5           bogo      1
# 0b1e1539f2cc45b7b9fa7c272da2e1d7       5          20       discount      1
# 2298d6c36e964ae4a3e7e9706d1fb8c2       3           7       discount      1
# fafdcd668e3743c1bb461111dcafc2a4       2          10       discount      1
# 5a8bc65990b245e5a138643cd4eb9837       0           0  informational      1
# f19421c1d4aa40978ebb69ca19b0e20d       5           5           bogo      1
# 2906b810c7d4411798c6938adc9daaa5       2          10       discount      1
#
#                                   mobile  social  web  duration
# offer_id
# ae264e3637204a6fb9bb56bc8210ddfd       1       1    0       168
# 4d5c57ea9a6940dd891ad53e9dbe8da0       1       1    1       120
# 3f207df678b143eea3cee63160fa8bed       1       0    1        96
# 9b98b8c7a33c4b65b9aebfe6a799e6d9       1       0    1       168
# 0b1e1539f2cc45b7b9fa7c272da2e1d7       0       0    1       240
# 2298d6c36e964ae4a3e7e9706d1fb8c2       1       1    1       168
# fafdcd668e3743c1bb461111dcafc2a4       1       1    1       240
# 5a8bc65990b245e5a138643cd4eb9837       1       1    0        72
# f19421c1d4aa40978ebb69ca19b0e20d       1       1    1       120
# 2906b810c7d4411798c6938adc9daaa5       1       0    1       168

# %%
portfolio.to_csv('../data/cln_portfolio.csv')

# %% [markdown]
# ### Cleaning and grouping transcript.json based on cust_id, event

# %%
transcript.rename(columns={'person': 'cust_id'}, inplace=True)
transcript.rename(columns={'time':'hours_till_action'},inplace=True)
transcript.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 4 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cust_id            306534 non-null  object
#  1   event              306534 non-null  object
#  2   value              306534 non-null  object
#  3   hours_till_action  306534 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 9.4+ MB

# %% [markdown]
# #### Unpacking value column into seperate columns

# %%
transcript = pd.concat([transcript, transcript['value'].apply(pd.Series)], axis=1)
# selecting from offer id and offer_id for different events
transcript['offer_id_new'] = np.where(transcript['offer id'].isnull() & transcript['offer_id'].notnull(),transcript['offer_id'],transcript['offer id'])
transcript.drop(['offer id','offer_id'],axis=1,inplace=True)
transcript.drop(['value'],axis=1,inplace=True)
transcript.rename(columns={'offer_id_new':'offer_id'},inplace=True)
transcript.sample(10)
# Out:
#                                  cust_id            event  hours_till_action  \
# 111168  7f0124b2a6e94e8fba10c4055d8edde3   offer received                336
# 202846  e6d3335fdf2c4cd2ac8edcd2bb06b289   offer received                504
# 93205   a10162dac5614ce28bc0e2d154e2224c  offer completed                240
# 38115   83377d650e4246fa96240dcdfe44e3be      transaction                 78
# 221787  7920c1de943d4acfbb2ab5b623504125     offer viewed                510
# 153240  ea8ae9ebc89b41ffb097dabbf8fe3c24   offer received                408
# 184025  633c42afdb4d44599ca2683c720dc69b      transaction                444
# 280255  11e648deac3b4a98ad5c10bb398fd393      transaction                618
# 216716  b66473610fa74072a1345b6c93d52464     offer viewed                504
# 27631   5d6a854b87274cc6af6f95a83d321af5      transaction                 36
#
#         amount  reward                          offer_id
# 111168     NaN     NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 202846     NaN     NaN  3f207df678b143eea3cee63160fa8bed
# 93205      NaN     5.0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 38115     2.41     NaN                               NaN
# 221787     NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 153240     NaN     NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 184025    1.46     NaN                               NaN
# 280255    1.13     NaN                               NaN
# 216716     NaN     NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 27631     4.37     NaN                               NaN

# %%
transcript.to_csv('../data/cln_transcript.csv')

# %% [markdown]
# ### Merging all the datasets together

# %% [markdown]
# #### Joining Transcript and portfolio

# %%
total = transcript.merge(portfolio,how='left',on='offer_id')
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306534 entries, 0 to 306533
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cust_id            306534 non-null  object
#  1   event              306534 non-null  object
#  2   hours_till_action  306534 non-null  int64
#  3   amount             138953 non-null  float64
#  4   reward_x           33579 non-null   float64
#  5   offer_id           167581 non-null  object
#  6   reward_y           167581 non-null  float64
#  7   difficulty         167581 non-null  float64
#  8   offer_type         167581 non-null  object
#  9   email              167581 non-null  float64
#  10  mobile             167581 non-null  float64
#  11  social             167581 non-null  float64
#  12  web                167581 non-null  float64
#  13  duration           167581 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 35.1+ MB

# %% [markdown]
# #### Joining Transcript and profile

# %%
total = total.merge(profile,how='left',on='cust_id')
total.rename(columns={'reward_x':'reward_received', 'reward_y':'reward_defined'},inplace=True)
total.sample(10)
# Out:
#                                  cust_id            event  hours_till_action  \
# 206121  9e34cfea6818482197c2a5c397a2e256   offer received                504
# 192152  d087fd0166404163b7d1e1e7cf2a9ac7      transaction                468
# 209771  ff932c6f8bb641bd816955337d153676   offer received                504
# 44318   0b250fe9fab14dac96ba542a572da081     offer viewed                108
# 961     82d8f33acf684ed6b16260d1dc1b30d5   offer received                  0
# 168481  d351650b4dfa4351bcfa0ada32c51c63      transaction                414
# 33510   4ee75462df554af99b7ea4d5edb7f369      transaction                 60
# 104257  72412f41d944472dbba2183ae9af8a8e  offer completed                294
# 171387  e88f50ba90a44deaa3df2b72b0a3e1f7      transaction                420
# 50848   4d5618b1bd0c4d1693b860e5b4daac40      transaction                150
#
#         amount  reward_received                          offer_id  \
# 206121     NaN              NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 192152    0.22              NaN                               NaN
# 209771     NaN              NaN  4d5c57ea9a6940dd891ad53e9dbe8da0
# 44318      NaN              NaN  3f207df678b143eea3cee63160fa8bed
# 961        NaN              NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 168481   10.69              NaN                               NaN
# 33510    13.46              NaN                               NaN
# 104257     NaN              2.0  fafdcd668e3743c1bb461111dcafc2a4
# 171387    1.26              NaN                               NaN
# 50848     1.88              NaN                               NaN
#
#         reward_defined  difficulty     offer_type  email  mobile  social  web  \
# 206121             5.0         5.0           bogo    1.0     1.0     1.0  1.0
# 192152             NaN         NaN            NaN    NaN     NaN     NaN  NaN
# 209771            10.0        10.0           bogo    1.0     1.0     1.0  1.0
# 44318              0.0         0.0  informational    1.0     1.0     0.0  1.0
# 961                3.0         7.0       discount    1.0     1.0     1.0  1.0
# 168481             NaN         NaN            NaN    NaN     NaN     NaN  NaN
# 33510              NaN         NaN            NaN    NaN     NaN     NaN  NaN
# 104257             2.0        10.0       discount    1.0     1.0     1.0  1.0
# 171387             NaN         NaN            NaN    NaN     NaN     NaN  NaN
# 50848              NaN         NaN            NaN    NaN     NaN     NaN  NaN
#
#         duration gender   age became_member_on    income  days_as_member
# 206121     120.0      M  99.0       2018-01-15  108000.0          1044.0
# 192152       NaN      M  71.0       2017-12-04   63000.0          1086.0
# 209771     120.0      M  65.0       2015-09-29   76000.0          1883.0
# 44318       96.0      F  63.0       2016-03-04   85000.0          1726.0
# 961        168.0    NaN   NaN              NaT       NaN             NaN
# 168481       NaN      M  54.0       2017-03-27   61000.0          1338.0
# 33510        NaN      F  26.0       2016-06-21   35000.0          1617.0
# 104257     240.0      F  88.0       2016-01-17  105000.0          1773.0
# 171387       NaN      M  75.0       2013-12-15   50000.0          2536.0
# 50848        NaN      M  34.0       2018-01-31   52000.0          1028.0

# %% [markdown]
# #### Removing duplicates from transcript data

# %%
dupe = total[total.duplicated()]
dupe
# Out:
#                                  cust_id            event  hours_till_action  \
# 66123   3dde94fa581145cb9f206624f1a94d5a  offer completed                168
# 66783   e9fb6ed2cecb4980ba98c86abc9c91e3  offer completed                168
# 67614   a7dc060f6fc94ca7bf71fbb188187dca  offer completed                168
# 68562   30478a4c1e884a63a822aa87b833ed7a  offer completed                168
# 69218   84fb57a7fe8045a8bf6236738ee73a0f  offer completed                168
# ...                                  ...              ...                ...
# 297625  6ba2450a438540999e633a5d99c7c7a0  offer completed                672
# 299471  f39fe7ea4e5946378e6d224504b77797  offer completed                684
# 304756  0785f1fce0b04ba08e01c7d2ebab4917  offer completed                708
# 305551  b7e216b6472b46648272c29a52a86702  offer completed                714
# 306456  f3e801caeafe4899b3b989b586e74ac7  offer completed                714
#
#         amount  reward_received                          offer_id  \
# 66123      NaN              2.0  2906b810c7d4411798c6938adc9daaa5
# 66783      NaN             10.0  ae264e3637204a6fb9bb56bc8210ddfd
# 67614      NaN              5.0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 68562      NaN              3.0  2298d6c36e964ae4a3e7e9706d1fb8c2
# 69218      NaN             10.0  ae264e3637204a6fb9bb56bc8210ddfd
# ...        ...              ...                               ...
# 297625     NaN              5.0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 299471     NaN              5.0  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 304756     NaN              5.0  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 305551     NaN              2.0  fafdcd668e3743c1bb461111dcafc2a4
# 306456     NaN              5.0  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#         reward_defined  difficulty offer_type  email  mobile  social  web  \
# 66123              2.0        10.0   discount    1.0     1.0     0.0  1.0
# 66783             10.0        10.0       bogo    1.0     1.0     1.0  0.0
# 67614              5.0         5.0       bogo    1.0     1.0     0.0  1.0
# 68562              3.0         7.0   discount    1.0     1.0     1.0  1.0
# 69218             10.0        10.0       bogo    1.0     1.0     1.0  0.0
# ...                ...         ...        ...    ...     ...     ...  ...
# 297625             5.0         5.0       bogo    1.0     1.0     0.0  1.0
# 299471             5.0        20.0   discount    1.0     0.0     0.0  1.0
# 304756             5.0        20.0   discount    1.0     0.0     0.0  1.0
# 305551             2.0        10.0   discount    1.0     1.0     1.0  1.0
# 306456             5.0        20.0   discount    1.0     0.0     0.0  1.0
#
#         duration gender   age became_member_on    income  days_as_member
# 66123      168.0      F  51.0       2017-11-14   56000.0          1106.0
# 66783      168.0      M  78.0       2015-04-21   55000.0          2044.0
# 67614      168.0      O  60.0       2017-02-01   69000.0          1392.0
# 68562      168.0      F  73.0       2017-12-09   74000.0          1081.0
# 69218      168.0      F  64.0       2017-06-15  113000.0          1258.0
# ...          ...    ...   ...              ...       ...             ...
# 297625     168.0      M  28.0       2015-01-24   61000.0          2131.0
# 299471     240.0      F  54.0       2017-08-07   98000.0          1205.0
# 304756     240.0      F  51.0       2017-08-15   78000.0          1197.0
# 305551     240.0      M  53.0       2018-07-08  113000.0           870.0
# 306456     240.0      F  27.0       2017-06-27   40000.0          1246.0
#
# [397 rows x 19 columns]

# %%
total_dist = total.drop_duplicates()

# %% [markdown]
# ### Adding features to profile

# %%
total_dist['count'] = 1
total_dist.sample(10)
# Out:
# <ipython-input-17-cc641ef89b90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_dist['count'] = 1
#                                  cust_id            event  hours_till_action  \
# 86025   50b72821aa1a459698ad47ff4058c1ed      transaction                216
# 25125   6ab082b797c54160b62417326d5f0c39  offer completed                 30
# 34400   dee41cfae12043039ee3ed880778e7dc      transaction                 66
# 283980  da6c95e567f94dfdb54c16073807fcfe      transaction                630
# 183524  ca7bb6b5974c44c0a6de4cc8c1c53cd8     offer viewed                444
# 33696   81837e891cb6445894f7cf90e36d6e2e      transaction                 60
# 186990  b0d824ac00104503bddefcdf811f8c36      transaction                450
# 204534  9e3888d67fb44211814cc57556d09c72   offer received                504
# 172237  51a798763c81413ca71c4f1f0530a61c     offer viewed                420
# 129321  2b9346b366f54865ac8436867d969f7d     offer viewed                342
#
#         amount  reward_received                          offer_id  \
# 86025    34.66              NaN                               NaN
# 25125      NaN              5.0  f19421c1d4aa40978ebb69ca19b0e20d
# 34400    12.50              NaN                               NaN
# 283980   11.17              NaN                               NaN
# 183524     NaN              NaN  f19421c1d4aa40978ebb69ca19b0e20d
# 33696     9.41              NaN                               NaN
# 186990    1.60              NaN                               NaN
# 204534     NaN              NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 172237     NaN              NaN  2298d6c36e964ae4a3e7e9706d1fb8c2
# 129321     NaN              NaN  f19421c1d4aa40978ebb69ca19b0e20d
#
#         reward_defined  difficulty offer_type  email  mobile  social  web  \
# 86025              NaN         NaN        NaN    NaN     NaN     NaN  NaN
# 25125              5.0         5.0       bogo    1.0     1.0     1.0  1.0
# 34400              NaN         NaN        NaN    NaN     NaN     NaN  NaN
# 283980             NaN         NaN        NaN    NaN     NaN     NaN  NaN
# 183524             5.0         5.0       bogo    1.0     1.0     1.0  1.0
# 33696              NaN         NaN        NaN    NaN     NaN     NaN  NaN
# 186990             NaN         NaN        NaN    NaN     NaN     NaN  NaN
# 204534             5.0         5.0       bogo    1.0     1.0     0.0  1.0
# 172237             3.0         7.0   discount    1.0     1.0     1.0  1.0
# 129321             5.0         5.0       bogo    1.0     1.0     1.0  1.0
#
#         duration gender   age became_member_on    income  days_as_member  \
# 86025        NaN      M  72.0       2018-01-01   56000.0          1058.0
# 25125      120.0      F  59.0       2017-10-23   57000.0          1128.0
# 34400        NaN      F  68.0       2018-03-08   68000.0           992.0
# 283980       NaN      M  72.0       2017-09-09   39000.0          1172.0
# 183524     120.0      M  40.0       2013-12-09   65000.0          2542.0
# 33696        NaN      M  38.0       2017-08-17   69000.0          1195.0
# 186990       NaN    NaN   NaN              NaT       NaN             NaN
# 204534     168.0      M  71.0       2015-06-02   69000.0          2002.0
# 172237     168.0      F  45.0       2018-05-23   75000.0           916.0
# 129321     120.0      F  52.0       2016-11-11  108000.0          1474.0
#
#         count
# 86025       1
# 25125       1
# 34400       1
# 283980      1
# 183524      1
# 33696       1
# 186990      1
# 204534      1
# 172237      1
# 129321      1

# %% [markdown]
# #### Total counts for all events

# %%
count_of_events = pd.pivot_table(total_dist, values='count', index = 'cust_id', columns='event', aggfunc=np.sum)
count_of_events.rename(columns=lambda x: "Total "+x, inplace=True)
count_of_events
# Out:
# event                             Total offer completed  Total offer received  \
# cust_id
# 0009655768c64bdeb2e877511632db8f                    3.0                   5.0
# 00116118485d4dfda04fdbaba9a87b5c                    NaN                   2.0
# 0011e0d4e6b944f998e987f904e8c1e5                    3.0                   5.0
# 0020c2b971eb4e9188eac86d93036a77                    3.0                   5.0
# 0020ccbbb6d84e358d3414a3ff76cffd                    3.0                   4.0
# ...                                                 ...                   ...
# fff3ba4757bd42088c044ca26d73817a                    3.0                   6.0
# fff7576017104bcc8677a8d63322b5e1                    3.0                   5.0
# fff8957ea8b240a6b5e634b6ee8eafcf                    NaN                   3.0
# fffad4f4828548d1b5583907f2e9906b                    3.0                   4.0
# ffff82501cea40309d5fdd7edcca4a07                    6.0                   6.0
#
# event                             Total offer viewed  Total transaction
# cust_id
# 0009655768c64bdeb2e877511632db8f                 4.0                8.0
# 00116118485d4dfda04fdbaba9a87b5c                 2.0                3.0
# 0011e0d4e6b944f998e987f904e8c1e5                 5.0                5.0
# 0020c2b971eb4e9188eac86d93036a77                 3.0                8.0
# 0020ccbbb6d84e358d3414a3ff76cffd                 4.0               12.0
# ...                                              ...                ...
# fff3ba4757bd42088c044ca26d73817a                 3.0               11.0
# fff7576017104bcc8677a8d63322b5e1                 4.0                6.0
# fff8957ea8b240a6b5e634b6ee8eafcf                 2.0                5.0
# fffad4f4828548d1b5583907f2e9906b                 4.0               12.0
# ffff82501cea40309d5fdd7edcca4a07                 6.0               15.0
#
# [17000 rows x 4 columns]

# %%
profile_features = profile
profile_features = profile_features.merge(count_of_events,how='left',on='cust_id')
profile_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14825 entries, 0 to 14824
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 14825 non-null  object
#  1   age                    14825 non-null  int64
#  2   cust_id                14825 non-null  object
#  3   became_member_on       14825 non-null  datetime64[ns]
#  4   income                 14825 non-null  float64
#  5   days_as_member         14825 non-null  int64
#  6   Total offer completed  11986 non-null  float64
#  7   Total offer received   14820 non-null  float64
#  8   Total offer viewed     14675 non-null  float64
#  9   Total transaction      14492 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Individual event counts based on offer type and counts of their modes of delivery

# %%
event_group = total_dist.groupby('event')
offer_counts = dict()

for event, group in event_group:
    if event != 'transaction':        
        offer_counts[event] = pd.pivot_table(group, values='count', index='cust_id', columns='offer_type', aggfunc=np.sum)
        offer_counts[event].rename(columns=lambda x: event+" "+x+" count", inplace=True)
        count_of_delivery_by_event = group[['cust_id', 'email', 'social', 'mobile', 'web']]
        count_of_delivery_by_event = count_of_delivery_by_event.groupby(['cust_id']).sum()
        count_of_delivery_by_event.rename(columns=lambda x: event+"_via_"+x, inplace=True)
        profile_features = profile_features.merge(count_of_delivery_by_event,how='left',on='cust_id')
    else:
        offer_counts[event] = group.groupby(['cust_id'])['amount'].agg('sum').to_frame()
        offer_counts[event].rename(columns=lambda x: "Total transaction "+x, inplace=True)
    profile_features = profile_features.merge(offer_counts[event],how='left',on='cust_id')

profile_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14825 entries, 0 to 14824
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gender                              14825 non-null  object
#  1   age                                 14825 non-null  int64
#  2   cust_id                             14825 non-null  object
#  3   became_member_on                    14825 non-null  datetime64[ns]
#  4   income                              14825 non-null  float64
#  5   days_as_member                      14825 non-null  int64
#  6   Total offer completed               11986 non-null  float64
#  7   Total offer received                14820 non-null  float64
#  8   Total offer viewed                  14675 non-null  float64
#  9   Total transaction                   14492 non-null  float64
#  10  offer completed_via_email           11986 non-null  float64
#  11  offer completed_via_social          11986 non-null  float64
#  12  offer completed_via_mobile          11986 non-null  float64
#  13  offer completed_via_web             11986 non-null  float64
#  14  offer completed bogo count          8914 non-null   float64
#  15  offer completed discount count      9718 non-null   float64
#  16  offer received_via_email            14820 non-null  float64
#  17  offer received_via_social           14820 non-null  float64
#  18  offer received_via_mobile           14820 non-null  float64
#  19  offer received_via_web              14820 non-null  float64
#  20  offer received bogo count           13082 non-null  float64
#  21  offer received discount count       13042 non-null  float64
#  22  offer received informational count  9200 non-null   float64
#  23  offer viewed_via_email              14675 non-null  float64
#  24  offer viewed_via_social             14675 non-null  float64
#  25  offer viewed_via_mobile             14675 non-null  float64
#  26  offer viewed_via_web                14675 non-null  float64
#  27  offer viewed bogo count             12194 non-null  float64
#  28  offer viewed discount count         10991 non-null  float64
#  29  offer viewed informational count    7151 non-null   float64
#  30  Total transaction amount            14492 non-null  float64
# dtypes: datetime64[ns](1), float64(26), int64(2), object(2)
# memory usage: 3.6+ MB

# %%
profile_features.fillna(0, inplace=True)    
profile_features.sample(10)
# Out:
#       gender  age                           cust_id became_member_on  \
# 8455       M   46  e7f6dc2a3bb7493ca35cebbbe6e444bb       2013-09-12
# 3500       M   35  00e8d701c583461e81cc10053681a12b       2018-02-26
# 13251      M   49  eef5ea58662f4e27b591d39990c10ae2       2016-08-14
# 777        M   66  15705f6ebfe4407991e5707d830aacb7       2015-03-17
# 8823       M   64  882346bfc610473c8505199a5179d302       2017-09-10
# 8717       F   64  5917ca26c4984c5f8e950da09aaf46ce       2014-07-19
# 7934       F   79  36e540dd327144b58b77729db6167af4       2013-12-17
# 12959      F   63  b0fc778d61024cd29eea6273bec6ba5a       2018-01-01
# 7970       F   52  e61a428312024ef493facecdbf5188cb       2017-10-01
# 719        M   58  86dd4706a3054adbbaf7287b7fa9aade       2017-09-06
#
#          income  days_as_member  Total offer completed  Total offer received  \
# 8455    39000.0            2630                    1.0                   4.0
# 3500    70000.0            1002                    1.0                   4.0
# 13251   97000.0            1563                    4.0                   6.0
# 777     50000.0            2079                    0.0                   1.0
# 8823    69000.0            1171                    1.0                   3.0
# 8717    56000.0            2320                    0.0                   6.0
# 7934    50000.0            2534                    3.0                   4.0
# 12959  115000.0            1058                    3.0                   4.0
# 7970    76000.0            1150                    3.0                   4.0
# 719     83000.0            1175                    2.0                   5.0
#
#        Total offer viewed  Total transaction  ...  \
# 8455                  3.0               14.0  ...
# 3500                  3.0                7.0  ...
# 13251                 4.0                6.0  ...
# 777                   1.0                8.0  ...
# 8823                  3.0                4.0  ...
# 8717                  2.0                7.0  ...
# 7934                  4.0                6.0  ...
# 12959                 3.0                7.0  ...
# 7970                  3.0                7.0  ...
# 719                   4.0                3.0  ...
#
#        offer received discount count  offer received informational count  \
# 8455                             2.0                                 1.0
# 3500                             2.0                                 1.0
# 13251                            2.0                                 2.0
# 777                              0.0                                 0.0
# 8823                             1.0                                 1.0
# 8717                             3.0                                 1.0
# 7934                             1.0                                 1.0
# 12959                            1.0                                 0.0
# 7970                             2.0                                 1.0
# 719                              2.0                                 1.0
#
#        offer viewed_via_email  offer viewed_via_social  \
# 8455                      3.0                      2.0
# 3500                      3.0                      2.0
# 13251                     4.0                      4.0
# 777                       1.0                      1.0
# 8823                      3.0                      2.0
# 8717                      2.0                      2.0
# 7934                      4.0                      2.0
# 12959                     3.0                      3.0
# 7970                      3.0                      2.0
# 719                       4.0                      3.0
#
#        offer viewed_via_mobile  offer viewed_via_web  offer viewed bogo count  \
# 8455                       3.0                   3.0                      1.0
# 3500                       3.0                   3.0                      1.0
# 13251                      4.0                   3.0                      1.0
# 777                        1.0                   0.0                      1.0
# 8823                       3.0                   1.0                      1.0
# 8717                       2.0                   2.0                      2.0
# 7934                       4.0                   3.0                      2.0
# 12959                      3.0                   3.0                      3.0
# 7970                       3.0                   3.0                      1.0
# 719                        3.0                   3.0                      1.0
#
#        offer viewed discount count  offer viewed informational count  \
# 8455                           2.0                               0.0
# 3500                           1.0                               1.0
# 13251                          2.0                               1.0
# 777                            0.0                               0.0
# 8823                           1.0                               1.0
# 8717                           0.0                               0.0
# 7934                           1.0                               1.0
# 12959                          0.0                               0.0
# 7970                           1.0                               1.0
# 719                            2.0                               1.0
#
#        Total transaction amount
# 8455                      27.86
# 3500                      30.98
# 13251                    163.72
# 777                       32.51
# 8823                     508.74
# 8717                      11.69
# 7934                     107.43
# 12959                    194.68
# 7970                     160.44
# 719                       83.24
#
# [10 rows x 31 columns]

# %% [markdown]
# #### Average difficulty score and duration

# %%
avg_difficulty_duration = total_dist[['cust_id', 'difficulty', 'duration']]
avg_difficulty_duration = avg_difficulty_duration.groupby(['cust_id']).mean()
avg_difficulty_duration.rename(columns=lambda x: "avg_"+x, inplace=True)
avg_difficulty_duration.sample(10)
# Out:
#                                   avg_difficulty  avg_duration
# cust_id
# 09cb1b009f154a9a93af117920ddb353        8.846154    162.461538
# d885cede482e4a03b42991c72c254265        8.750000    150.000000
# e8e04794782945cd9c436f996a8ba64f       10.000000    189.600000
# 82feefcd3f904269afdabda68c9b73e2       10.785714    183.428571
# a2a61641e2d84d66b4c59266e4ddc4f9        6.000000    130.666667
# 8f5430f8f2f442abaf2e6661a26a22a4       13.214286    198.857143
# ebc303bcc1b44aa6b4d1762960451468        8.923077    179.076923
# 95e57e801cf84720b4249cc1d70314f5        5.538462    142.153846
# b23fd66b4bd4463b8382ff9007f7f861       10.769231    188.307692
# 5359ca16190a4a27b65e850b05f8c129        9.500000    164.000000

# %%
profile_features = profile_features.merge(avg_difficulty_duration,how='left',on='cust_id')
profile_features.sample(5)
# Out:
#       gender  age                           cust_id became_member_on   income  \
# 535        F   20  79aa711ee90c4297b1c6cb6f7d40421a       2018-02-03  60000.0
# 73         M   64  cbebad9819494b479dbf0c1207b4c0c5       2017-03-05  70000.0
# 12462      O   49  bd85eeff28ee40a2a6b0c4829a4f211e       2017-01-10  95000.0
# 499        F   50  55540073b2be424a9729852465b1b8df       2018-01-06  75000.0
# 14506      M   91  da7aced8db154427a94a9008200267e4       2013-12-15  49000.0
#
#        days_as_member  Total offer completed  Total offer received  \
# 535              1025                    0.0                   4.0
# 73               1360                    4.0                   4.0
# 12462            1414                    3.0                   6.0
# 499              1053                    3.0                   4.0
# 14506            2536                    2.0                   5.0
#
#        Total offer viewed  Total transaction  ...  offer viewed_via_email  \
# 535                   4.0                8.0  ...                     4.0
# 73                    4.0                9.0  ...                     4.0
# 12462                 6.0                7.0  ...                     6.0
# 499                   3.0               11.0  ...                     3.0
# 14506                 2.0                8.0  ...                     2.0
#
#        offer viewed_via_social  offer viewed_via_mobile  offer viewed_via_web  \
# 535                        3.0                      4.0                   3.0
# 73                         3.0                      3.0                   4.0
# 12462                      5.0                      6.0                   4.0
# 499                        3.0                      3.0                   2.0
# 14506                      2.0                      2.0                   2.0
#
#        offer viewed bogo count  offer viewed discount count  \
# 535                        0.0                          3.0
# 73                         1.0                          3.0
# 12462                      2.0                          1.0
# 499                        0.0                          2.0
# 14506                      1.0                          1.0
#
#        offer viewed informational count  Total transaction amount  \
# 535                                 1.0                     17.40
# 73                                  0.0                    140.34
# 12462                               3.0                    147.99
# 499                                 1.0                    221.95
# 14506                               0.0                     28.26
#
#        avg_difficulty  avg_duration
# 535          6.000000         144.0
# 73          11.750000         192.0
# 12462        5.400000         113.6
# 499          6.100000         170.4
# 14506        9.222222         160.0
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Total rewards defined and total rewards received

# %%
full_rewards = total_dist[['cust_id', 'reward_defined', 'reward_received']]
sum_rewards = full_rewards.groupby(['cust_id']).sum()
sum_rewards.rename(columns=lambda x: "total_"+x, inplace=True)
sum_rewards.sample(10)
# Out:
#                                   total_reward_defined  total_reward_received
# cust_id
# 38c60a8b1136438690a80c3b5a211200                  65.0                    0.0
# ca5815021d3c42e2bef68f023a7764d0                  28.0                    0.0
# 05fc9b1280454d84a712d8cb763c7c79                  95.0                   25.0
# 848d42f1ff704218827e8efeadca474d                  14.0                    3.0
# 61e7bf20af4c434ab2d89cdc565d8046                  27.0                    0.0
# d52a2606f8654e009920fd75d0fdbf45                  39.0                    0.0
# dce6d06c87cb4657bc6b123cc35373d1                  65.0                   15.0
# 4fdfb0cfb2164596ac8df0661a13330a                  39.0                   13.0
# 6bb33215d6c549f3afc5e743b8ff3a85                  35.0                    0.0
# 46f14dabab414aadaf119bc1e633ea3e                  10.0                    0.0

# %%
profile_features = profile_features.merge(sum_rewards,how='left',on='cust_id')
profile_features.sample(5)
# Out:
#       gender  age                           cust_id became_member_on   income  \
# 4824       M   76  66a04ad46d83408ea8e2e28e8ccf3300       2016-11-23  85000.0
# 12689      M   63  815b2181c57b438086c2661cc6c33d78       2018-01-09  95000.0
# 4409       M   32  c4875ed3bb9e4823bdd7ab5171326dbb       2017-09-06  35000.0
# 9374       M   20  b8f309e5c6b34d1b8158468dcf6cbdec       2017-12-05  32000.0
# 7758       M   28  da3d478411cd4a30a6efa9d673530f00       2017-05-23  30000.0
#
#        days_as_member  Total offer completed  Total offer received  \
# 4824             1462                    3.0                   5.0
# 12689            1050                    0.0                   4.0
# 4409             1175                    0.0                   5.0
# 9374             1085                    0.0                   3.0
# 7758             1281                    2.0                   5.0
#
#        Total offer viewed  Total transaction  ...  offer viewed_via_mobile  \
# 4824                  5.0                6.0  ...                      4.0
# 12689                 4.0                4.0  ...                      4.0
# 4409                  3.0                6.0  ...                      3.0
# 9374                  2.0                0.0  ...                      2.0
# 7758                  3.0               14.0  ...                      3.0
#
#        offer viewed_via_web  offer viewed bogo count  \
# 4824                    3.0                      2.0
# 12689                   2.0                      3.0
# 4409                    2.0                      1.0
# 9374                    0.0                      0.0
# 7758                    1.0                      1.0
#
#        offer viewed discount count  offer viewed informational count  \
# 4824                           2.0                               1.0
# 12689                          0.0                               1.0
# 4409                           1.0                               1.0
# 9374                           0.0                               2.0
# 7758                           0.0                               2.0
#
#        Total transaction amount  avg_difficulty  avg_duration  \
# 4824                     146.09       10.307692    158.769231
# 12689                    103.13        6.250000    120.000000
# 4409                      13.06        6.750000    132.000000
# 9374                       0.00        2.000000     91.200000
# 7758                      87.57        5.000000    134.400000
#
#        total_reward_defined  total_reward_received
# 4824                   81.0                   25.0
# 12689                  50.0                    0.0
# 4409                   31.0                    0.0
# 9374                   10.0                    0.0
# 7758                   34.0                    7.0
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Count of offer delivery method

# %%
count_of_delivery = total_dist[['cust_id', 'email', 'social', 'mobile', 'web']]
count_of_delivery = count_of_delivery.groupby(['cust_id']).sum()
count_of_delivery.rename(columns=lambda x: "Total_offers_via_"+x, inplace=True)
count_of_delivery.sample(10)
# Out:
#                                   Total_offers_via_email  \
# cust_id
# 7ee0436c7abc4526a1d97f598701b4a8                    10.0
# 4f1676b2b52549fb9ffd6c9980437df9                    11.0
# d8d2466b53034391b840556be4b1be2c                    14.0
# 63f1bfb1a79949bf9bc0d0b8b184fe4e                    12.0
# 542c41f5afc049e7ae7d4721ace9d286                    12.0
# 2531d3b6001a4d48bff0a91ceceb97a0                    15.0
# abc440bf04f4476d943077f226cbedf7                     8.0
# dadae228edc442d59471e7e8d42e1d9e                    12.0
# a414d8006bc24fe18b564304efdf559b                    12.0
# b5105f071088481c8382eb9f73cd6a27                     5.0
#
#                                   Total_offers_via_social  \
# cust_id
# 7ee0436c7abc4526a1d97f598701b4a8                      8.0
# 4f1676b2b52549fb9ffd6c9980437df9                      8.0
# d8d2466b53034391b840556be4b1be2c                     12.0
# 63f1bfb1a79949bf9bc0d0b8b184fe4e                     12.0
# 542c41f5afc049e7ae7d4721ace9d286                      6.0
# 2531d3b6001a4d48bff0a91ceceb97a0                     11.0
# abc440bf04f4476d943077f226cbedf7                      2.0
# dadae228edc442d59471e7e8d42e1d9e                      7.0
# a414d8006bc24fe18b564304efdf559b                      9.0
# b5105f071088481c8382eb9f73cd6a27                      2.0
#
#                                   Total_offers_via_mobile  \
# cust_id
# 7ee0436c7abc4526a1d97f598701b4a8                     10.0
# 4f1676b2b52549fb9ffd6c9980437df9                      8.0
# d8d2466b53034391b840556be4b1be2c                     12.0
# 63f1bfb1a79949bf9bc0d0b8b184fe4e                     12.0
# 542c41f5afc049e7ae7d4721ace9d286                     12.0
# 2531d3b6001a4d48bff0a91ceceb97a0                     13.0
# abc440bf04f4476d943077f226cbedf7                      5.0
# dadae228edc442d59471e7e8d42e1d9e                     12.0
# a414d8006bc24fe18b564304efdf559b                     12.0
# b5105f071088481c8382eb9f73cd6a27                      4.0
#
#                                   Total_offers_via_web
# cust_id
# 7ee0436c7abc4526a1d97f598701b4a8                   8.0
# 4f1676b2b52549fb9ffd6c9980437df9                   9.0
# d8d2466b53034391b840556be4b1be2c                  11.0
# 63f1bfb1a79949bf9bc0d0b8b184fe4e                   9.0
# 542c41f5afc049e7ae7d4721ace9d286                  10.0
# 2531d3b6001a4d48bff0a91ceceb97a0                  13.0
# abc440bf04f4476d943077f226cbedf7                   8.0
# dadae228edc442d59471e7e8d42e1d9e                   8.0
# a414d8006bc24fe18b564304efdf559b                   9.0
# b5105f071088481c8382eb9f73cd6a27                   3.0

# %%
profile_features = profile_features.merge(count_of_delivery,how='left',on='cust_id')
profile_features.sample(5)
# Out:
#       gender  age                           cust_id became_member_on   income  \
# 13676      M   35  d6cd472ecc5144f5b3fbe284e8da942f       2016-05-11  33000.0
# 7764       M   65  86e85d52b66549dd866e69eda19919c2       2017-09-15  52000.0
# 14643      M   21  c04f144ebb8e4694b3c954574c7631bf       2016-04-28  42000.0
# 5719       M   68  74e06417ac8043b08b5f66b3a0a16c4a       2018-01-20  40000.0
# 11370      M   29  2bb22e7931aa49ebabff26b9cbc6260a       2018-01-19  45000.0
#
#        days_as_member  Total offer completed  Total offer received  \
# 13676            1658                    3.0                   5.0
# 7764             1166                    4.0                   5.0
# 14643            1671                    0.0                   3.0
# 5719             1039                    0.0                   4.0
# 11370            1040                    2.0                   5.0
#
#        Total offer viewed  Total transaction  ...  \
# 13676                 2.0               14.0  ...
# 7764                  4.0                5.0  ...
# 14643                 3.0               18.0  ...
# 5719                  3.0                2.0  ...
# 11370                 3.0               19.0  ...
#
#        offer viewed informational count  Total transaction amount  \
# 13676                               0.0                    100.55
# 7764                                0.0                    102.67
# 14643                               1.0                     54.37
# 5719                                0.0                      6.63
# 11370                               1.0                     47.49
#
#        avg_difficulty  avg_duration  total_reward_defined  \
# 13676       12.000000    211.200000                  51.0
# 7764         9.615385    179.076923                  62.0
# 14643        6.666667    104.000000                  40.0
# 5719        10.714286    161.142857                  45.0
# 11370       10.100000    160.800000                  44.0
#
#        total_reward_received  Total_offers_via_email  Total_offers_via_social  \
# 13676                   12.0                    10.0                      5.0
# 7764                    19.0                    13.0                      9.0
# 14643                    0.0                     6.0                      6.0
# 5719                     0.0                     7.0                      4.0
# 11370                    8.0                    10.0                      7.0
#
#        Total_offers_via_mobile  Total_offers_via_web
# 13676                      7.0                   8.0
# 7764                      12.0                  10.0
# 14643                      6.0                   4.0
# 5719                       5.0                   7.0
# 11370                      7.0                   8.0
#
# [5 rows x 39 columns]

# %% [markdown]
# #### View and completion ratio

# %%
profile_features['total_view_ratio'] = round(profile_features['Total offer viewed']/profile_features['Total offer received'], 2)
profile_features['total_completion_ratio'] = round(profile_features['Total offer completed']/profile_features['Total offer received'], 3) 
profile_features.sample(5)
# Out:
#       gender  age                           cust_id became_member_on   income  \
# 8985       M   18  5a52e27405c84e58a0d7414562df9e10       2018-04-17  40000.0
# 3178       F   43  e2fd3352911844f0b3bc2965978c2798       2017-07-05  66000.0
# 13352      M   35  3d3bad0437e3459d873772f8023653ac       2016-09-01  64000.0
# 2484       M   76  990080173c3f4871bb8634a9b50e118a       2017-11-18  75000.0
# 3416       M   43  5e44bc50a2b84b0a89d7246f5a85617e       2018-07-23  99000.0
#
#        days_as_member  Total offer completed  Total offer received  \
# 8985              952                    0.0                   6.0
# 3178             1238                    3.0                   3.0
# 13352            1545                    3.0                   6.0
# 2484             1102                    2.0                   2.0
# 3416              855                    3.0                   5.0
#
#        Total offer viewed  Total transaction  ...  avg_difficulty  \
# 8985                  4.0                4.0  ...        5.000000
# 3178                  1.0               12.0  ...       10.714286
# 13352                 2.0               11.0  ...        7.000000
# 2484                  1.0                3.0  ...        8.000000
# 3416                  5.0                6.0  ...        8.846154
#
#        avg_duration  total_reward_defined  total_reward_received  \
# 8985     127.200000                  26.0                    0.0
# 3178     188.571429                  25.0                   11.0
# 13352    168.000000                  38.0                   11.0
# 2484     139.200000                  40.0                   15.0
# 3416     173.538462                  71.0                   15.0
#
#        Total_offers_via_email  Total_offers_via_social  \
# 8985                     10.0                      8.0
# 3178                      7.0                      5.0
# 13352                    11.0                      6.0
# 2484                      5.0                      3.0
# 3416                     13.0                     13.0
#
#        Total_offers_via_mobile  Total_offers_via_web  total_view_ratio  \
# 8985                      10.0                   6.0              0.67
# 3178                       5.0                   7.0              0.33
# 13352                     10.0                  11.0              0.33
# 2484                       5.0                   5.0              0.50
# 3416                      13.0                  11.0              1.00
#
#        total_completion_ratio
# 8985                      0.0
# 3178                      1.0
# 13352                     0.5
# 2484                      1.0
# 3416                      0.6
#
# [5 rows x 41 columns]

# %% [markdown]
# #### Avg_transaction_amt and transactions_per_membership_days

# %%
profile_features['avg_transaction_amt'] = round(profile_features['Total transaction amount']/profile_features['Total transaction'], 2)
profile_features['transactions_per_membership_days'] = profile_features['Total transaction']/profile_features['days_as_member']
profile_features.fillna(0, inplace=True)
profile_features.sample(5)
# Out:
#       gender  age                           cust_id became_member_on   income  \
# 11989      M   67  0b680efe1a0a40788ebb6fb2c587b4a7       2017-08-13  67000.0
# 11694      M   49  8956d5a699344f2ca654cda962b0d953       2016-08-26  70000.0
# 10940      F   65  2db15c88abc743109a09cd8c066eb5da       2017-12-12  46000.0
# 8690       M   86  6d43ca076aef48c3a20af0ce5cce1a52       2016-01-13  44000.0
# 12708      M   59  6b64bd90a25b4c1399eb9f6e29a4d6f4       2017-12-08  65000.0
#
#        days_as_member  Total offer completed  Total offer received  \
# 11989            1199                    0.0                   3.0
# 11694            1551                    3.0                   5.0
# 10940            1078                    5.0                   5.0
# 8690             1777                    1.0                   5.0
# 12708            1082                    0.0                   3.0
#
#        Total offer viewed  Total transaction  ...  total_reward_defined  \
# 11989                 2.0                4.0  ...                  30.0
# 11694                 5.0               14.0  ...                  30.0
# 10940                 4.0               13.0  ...                  61.0
# 8690                  3.0               11.0  ...                  36.0
# 12708                 3.0                6.0  ...                  24.0
#
#        total_reward_received  Total_offers_via_email  Total_offers_via_social  \
# 11989                    0.0                     5.0                      3.0
# 11694                   10.0                    13.0                      8.0
# 10940                   21.0                    14.0                     12.0
# 8690                     3.0                     9.0                      7.0
# 12708                    0.0                     6.0                      0.0
#
#        Total_offers_via_mobile  Total_offers_via_web  total_view_ratio  \
# 11989                      5.0                   3.0              0.67
# 11694                     13.0                  11.0              1.00
# 10940                     14.0                  11.0              0.80
# 8690                       8.0                   7.0              0.60
# 12708                      6.0                   6.0              1.00
#
#        total_completion_ratio  avg_transaction_amt  \
# 11989                     0.0                17.01
# 11694                     0.6                16.09
# 10940                     1.0                11.32
# 8690                      0.2                 2.58
# 12708                     0.0                 3.06
#
#        transactions_per_membership_days
# 11989                          0.003336
# 11694                          0.009026
# 10940                          0.012059
# 8690                           0.006190
# 12708                          0.005545
#
# [5 rows x 43 columns]

# %%
len(profile_features[profile_features['Total offer viewed'] < profile_features['Total offer completed']])
# Out:
# 1932

# %%
profile_features.to_csv('../data/xtr_profile.csv')
